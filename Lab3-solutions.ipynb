# %% [markdown]
# # Εργαστήριο 3-Απαντήσεις

# %% [markdown]
# ## Άσκηση 3.1

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import BasicAer, execute

q = QuantumRegister(1,'q')
circ = QuantumCircuit(q)
circ.u3(1,1,1,q[0])
circ.draw(output='mpl')

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(circ, backend)
result = job.result()
outputstate = result.get_statevector(circ)
print(outputstate)
# Out:
# [0.87758256+0.j         0.25903472+0.40342268j]

# %% [markdown]
# ## Άσκηση 3.2

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute
from qiskit import BasicAer
q = QuantumRegister(2,'q')
c = ClassicalRegister(2,'c')
circ = QuantumCircuit(q,c)
circ.u3(1,1,1,q[0])
circ.cx(q[0],q[1])
circ.measure(q,c)
circ.draw(output='mpl')

# %%
backend_sim = BasicAer.get_backend('qasm_simulator')
job_sim = execute(circ, backend_sim, shots=1024)
result_sim = job_sim.result()
counts = result_sim.get_counts(circ)
print(counts)
# Out:
# {'00': 774, '11': 250}

# %% [markdown]
# ## Άσκηση 3.3

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import BasicAer, execute
q = QuantumRegister(3, 'q')
c = ClassicalRegister(2, 'c')
circ = QuantumCircuit(q,c)
circ.u3(1,1,1,q[0])
circ.h(q[1])
circ.cx(q[1],q[2])
circ.cx(q[0],q[1])
circ.h(q[0])
circ.barrier()
circ.cx(q[1],q[2])
circ.cz(q[0],q[2])
circ.barrier()
circ.measure(q[0],c[0])
circ.measure(q[1],c[1])
circ.draw(output='mpl')

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(circ, backend)
result = job.result()
outputstate = result.get_statevector(circ)
print(outputstate)
# Out:
# [0.43879128+0.j         0.43879128+0.j         0.43879128+0.j
#  0.43879128+0.j         0.12951736+0.20171134j 0.12951736+0.20171134j
#  0.12951736+0.20171134j 0.12951736+0.20171134j]

# %% [markdown]
# ## Άσκηση 3.4

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from math import pi
q = QuantumRegister(3, 'q')
circ = QuantumCircuit(q)
circ.x(q[1])
circ.barrier()
circ.u3(6,-pi,pi/2,q[0])
circ.u3(6,0,0,q[1])
circ.u1(6,q[2])
circ.draw(output='mpl')

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(circ, backend)
result = job.result()
outputstate = result.get_statevector(circ)
print(outputstate)
# Out:
# [0.13970775+0.j 0.01991486+0.j 0.98008514+0.j 0.13970775+0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from math import pi
q = QuantumRegister(4, 'q')
circ = QuantumCircuit(q)
circ.x(q[1])
circ.barrier()
circ.u3(-pi/2,0,0,q[0])
circ.u3(pi/2,pi/2,-pi/2,q[1])
circ.cx(q[0],q[3])
circ.cx(q[1],q[3])
circ.cx(q[2],q[3])
circ.u1(6,q[3])
circ.cx(q[2],q[3])
circ.cx(q[1],q[3])
circ.cx(q[0],q[3])
circ.barrier()
circ.u3(pi/2,0,0,q[0])
circ.u3(-pi/2,pi/2,-pi/2,q[1])
circ.draw(output='mpl')

# %%
backend = BasicAer.get_backend('statevector_simulator')
job = execute(circ, backend)
result = job.result()
outputstate = result.get_statevector(circ)
print(outputstate)
# Out:
# [ 0.        +0.j         -0.13970775+0.01991486j  0.98008514-0.13970775j
#   0.        +0.j          0.        +0.j          0.        +0.j
#   0.        +0.j          0.        +0.j          0.        +0.j
#   0.        +0.j          0.        +0.j          0.        +0.j
#   0.        +0.j          0.        +0.j          0.        +0.j
#   0.        +0.j        ]
